# %%
import pandas as pd
import os
import glob

# %%
UnID2020 = r'C:\Users\emjcr\Desktop\Butler Homework\Tableau-Challenge\201307-201402-citibike-tripdata\CSV\df2020.csv'

# %%
df = pd.read_csv(UnID2020)
df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1                377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2                288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3                435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4                231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...              ...                       ...                       ...
# 336797          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 336798          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 336799          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 336800           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 336801          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#         start station id start station name  start station latitude  \
# ...

# %%
df['start station id'] = df['start station id'].apply(str)
df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1                377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2                288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3                435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4                231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...              ...                       ...                       ...
# 336797          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 336798          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 336799          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 336800           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 336801          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
df['end station id'] = df['end station id'].apply(str)
df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1                377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2                288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3                435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4                231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...              ...                       ...                       ...
# 336797          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 336798          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 336799          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 336800           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 336801          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id            object
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id              object
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
df['uniID'] = df['start station id'] + '_' + df['end station id']
df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1                377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2                288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3                435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4                231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...              ...                       ...                       ...
# 336797          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 336798          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 336799          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 336800           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 336801          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
df['uniID'].value_counts()
# Out:
# 3192_3192    7657
# 3199_3199    5014
# 3276_3276    3166
# 3205_3205    2675
# 3194_3195    2398
#              ...
# 3186_525        1
# 3187_3992       1
# 3278_3679       1
# 3184_127        1
# 3269_3256       1
# Name: uniID, Length: 2714, dtype: int64

# %%
unidf2020 = df
unidf2020
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1                377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2                288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3                435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4                231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...              ...                       ...                       ...
# 336797          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 336798          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 336799          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 336800           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 336801          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
review_uniID = df.loc[df['uniID'] == '3192_3192',]
review_uniID
# Out:
#         tripduration                 starttime                  stoptime  \
# 738             2151  2020-01-02 12:12:56.8880  2020-01-02 12:48:48.6960
# 739             2142  2020-01-02 12:13:16.1350  2020-01-02 12:48:58.2760
# 740             2219  2020-01-02 12:13:17.9690  2020-01-02 12:50:17.6880
# 741             2214  2020-01-02 12:13:27.1400  2020-01-02 12:50:21.8550
# 744             2021  2020-01-02 12:14:36.3050  2020-01-02 12:48:18.2910
# ...              ...                       ...                       ...
# 334659          1742  2020-12-24 14:59:52.0940  2020-12-24 15:28:55.0160
# 334830          1973  2020-12-25 15:01:45.4400  2020-12-25 15:34:38.8210
# 334849          2582  2020-12-25 15:54:14.0740  2020-12-25 16:37:16.2560
# 336267          2620  2020-12-30 12:39:42.7630  2020-12-30 13:23:23.5030
# 336700          2819  2020-12-31 16:55:22.4910  2020-12-31 17:42:21.9460
#
#        start station id  start station name  start station latitude  \
# ...

# %%
unidf2020.to_csv(r'C:\Users\emjcr\Desktop\Butler Homework\Tableau-Challenge\201307-201402-citibike-tripdata\CSV\unidf2020.csv', index=False)
